# %% [markdown]
# <a href="https://colab.research.google.com/github/prasanna-chintamaneni/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Mod8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-10 06:29:02--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   124MB/s    in 0.6s
#
# 2023-05-10 06:29:08 (124 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3984 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2485    1307.0813v2  Learning policies that generalize across multi...  stat
# 14043  1706.09648v1  We consider the problem of power demand foreca...    cs
# 51     1511.05234v2  We address the problem of Visual Question Answ...    cs
# 26956  1701.05524v3  Synthetic images rendered from 3D CAD models a...    cs
# 19183   1304.1684v1  Probability answer set programming is a declar...    cs
# ...             ...                                                ...   ...
# 27861  1704.07325v1  We present an optical flow estimation approach...    cs
# 6105   1607.04903v3  A major challenge in the training of recurrent...  stat
# 9327    1202.2892v1  In this paper we propose two new algorithms ba...    cs
# 3989    0908.3148v2  The term quantum neural computing indicates a ...    cs
# 7840   1803.07658v1  Sparse models for high-dimensional linear regr...  stat
#
#                                                    title  year  \
# 2485                            Multi-Task Policy Search  2013
# 14043  Machine Learning Approaches to Energy Consumpt...  2017
# 51     Ask, Attend and Answer: Exploring Question-Gui...  2015
# 26956  Synthetic to Real Adaptation with Generative C...  2017
# 19183  Probability Aggregates in Probability Answer S...  2013
# ...                                                  ...   ...
# 27861  Accurate Optical Flow via Direct Cost Volume P...  2017
# 6105      Learning Unitary Operators with Help From u(n)  2016
# 9327   Recommender System Based on Algorithm of Biclu...  2012
# 3989            Another Look at Quantum Neural Computing  2009
# 7840   Graph-based regularization for regression prob...  2018
#
#                                                 keywords
# 2485   [generalize, important, challenging, reinforce...
# 14043  [forecasting, residential, approaches, recurre...
# 51     [answering, understanding, photograph, approac...
# 26956  [synthetic, augmenting, recognition, algorithm...
# 19183  [probability, programming, declarative, progra...
# ...                                                  ...
# 27861  [estimation, dimensional, structural, pipeline...
# 6105   [challenge, recurrent, vanishing, exploding, p...
# 9327   [algorithms, biclustering, recommender, educat...
# 3989   [computing, indicates, functioning, structures...
# 7840   [dimensional, regression, substantial, attenti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2485     [generalize, important, challenging, reinforce...
# 14043    [forecasting, residential, approaches, recurre...
# 51       [answering, understanding, photograph, approac...
# 26956    [synthetic, augmenting, recognition, algorithm...
# 19183    [probability, programming, declarative, progra...
#                                ...
# 7012     [similarity, clustering, supervised, according...
# 10464    [generative, typically, committed, assumptions...
# 21575    [theoretical, obozinski, regression, selection...
# 38996    [anisotropic, diffusion, processing, technique...
# 18481    [knowledge, attributed, subjective, knowledge,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8810 words.
# Out of those 4517 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="1c6d1cf1-af44-4dfe-b04d-e777bf1e926b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c6d1cf1-af44-4dfe-b04d-e777bf1e926b")) {                    Plotly.newPlot(                        "1c6d1cf1-af44-4dfe-b04d-e777bf1e926b",                        [{"x":["individual","generalizes","challenging","applications","experiments","generalize","important","continuous","imitation","parametrized","reinforcement","potential","variations","requiring","knowledge","principled","approaches","nonlinear","impractical","especially","implement","requirements","considered","households","consumption","recommended","algorithm","discussed","residential","techniques","prediction","literature","predictions","efficient","deployments","recurrent","forecasting","uncertainty","framework","performance","activations","questions","concatenates","convolutional","information","visualize","published","constitutes","understand","synthetic","architecture","inference","captioning","mechanism","answering","computing","exploring","understanding","attention","specifically","different","considers","adaptation","significantly","improving","recognition","preserving","generative","realistic","experimentally","alignment","synthesize","statistics","correlation","leverages","classifiers","augmenting","algorithms","photorealistic","statistic","discrepancy","benchmark","generated","including","reasoning","effective","semantics","arbitrary","aggregates","introduce","representing","declarative","representation","probability","consequently","interesting","aggregate","classical","nonmonotonic","disjunctive","programming","algebraic","similarity","equivalence","iterative","existence","considering","application","criterion","relationship","immediate","subtraction","properties","alzheimers","hippocampal","automatic","cognitive","promising","diagnostics","augmentation","determination","balancing","diagnosis","impairment","diffusion","extraction","comparison","furthermore","modalities","resonance","classification","initiative","tomography","structural","alzheimer","neuroimaging","extensive","functional","direction","supervised","decisions","processing","perception","rationality","possibilities","incorporation","conditions","normative","emergency","prescriptive","technological","addresses","searching","descriptive","presented","classifying","numerical","regarding","surveying","conclusions","usefulness","deblurring","degradation","improvements","experimental","redundancies","resolution","desirable","observation","characterizing","processes","projection","competitive","consistencies","achieving","denoising","optimized","interleaved","efficiently","architectures","restoration","denoisers","rotations","structured","collections","collection","trainable","documents","emulating","background","substrate","performed","historical","containing","handwritten","structures","production","disjunction","minimization","threshold"],"y":[117,26,246,444,610,59,359,114,6,2,103,165,73,61,332,22,445,62,7,114,89,48,144,3,25,4,822,49,3,376,204,130,80,422,1,152,23,75,578,854,27,57,2,365,671,14,30,11,74,148,267,220,13,107,44,136,41,163,183,163,754,30,66,266,117,371,50,134,62,55,65,14,65,71,27,120,12,574,7,9,15,190,186,236,111,275,88,99,5,358,67,13,363,164,26,68,17,106,6,4,114,18,138,23,64,28,65,254,48,59,9,5,233,7,2,191,53,131,9,28,13,9,45,3,23,141,161,159,37,26,499,8,15,88,4,7,166,43,63,197,63,291,45,9,15,10,137,8,4,3,6,52,29,17,188,33,80,32,1,13,22,7,14,116,375,2,116,31,48,16,104,43,120,4,76,41,62,5,158,136,13,2,14,112,14,68,21,72,4,69,3,109,18,47,39,134,27,3,59,37],"type":"bar"},{"x":["individual","generalizes","challenging","applications","experiments","generalize","important","continuous","imitation","parametrized ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4517,), (4517, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8158333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style=''>Model</span> <span style=''>Checking</span> <span style=''>for</span> <span style=''>Complex</span> <span style='background-color:rgba(0, 255, 0, 0.6307692307692307);'>Cognitive</span> <span style=''>Tasks</span> <span style=''>A</span> <span style=''>case</span> <span style=''>study</span> <span style=''>in</span> <span style=''>human</span> <span style=''>robot</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interaction</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>to</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>checking</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.6470588235294117);'>synthesize</span> <span style=''>optimal</span> <span style=''>robot</span> <span style=''>policies</span> <span style=''>in</span> <span style=''>multi</span> <span style=''>tasking</span> <span style='background-color:rgba(0, 255, 0, 0.7377049180327868);'>autonomous</span> <span style=''>systems</span> <span style=''>that</span> <span style=''>are</span> <span style=''>subject</span> <span style=''>to</span> <span style=''>human</span> <span style=''>robot</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interaction</span> <span style=''>Given</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.7777777777777778);'>convincing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>evidence</span> <span style=''>that</span> <span style=''>human</span> <span style=''>behavior</span> <span style=''>can</span> <span style=''>be</span> <span style=''>related</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reinforcement</span> <span style=''>models</span> <span style=''>we</span> <span style=''>take</span> <span style=''>as</span> <span style=''>input</span> <span style=''>a</span> <span style=''>well</span> <span style=''>studied</span> <span style=''>Q</span> <span style=''>table</span> <span style=''>model</span> <span style=''>of</span> <span style=''>the</span> <span style=''>human</span> <span style=''>behavior</span> <span style=''>for</span> <span style=''>flexible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>scenarios</span> <span style=''>We</span> <span style=''>first</span> <span style=''>describe</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5000000000000001);'>automated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>to</span> <span style=''>distill</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>decision</span> <span style=''>process</span> <span style=''>(MDP)</span> <span style=''>for</span> <span style=''>the</span> <span style=''>human</span> <span style=''>in</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>but</span> <span style=''>fixed</span> <span style=''>scenario</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distinctive</span> <span style=''>issue</span> <span style=''>is</span> <span style=''>that</span> <span style=''>in</span> <span style=''>contrast</span> <span style=''>to</span> <span style=''>existing</span> <span style=''>models</span> <span style=''>under</span> <span style='background-color:rgba(0, 255, 0, 0.5862068965517242);'>specification</span> <span style=''>of</span> <span style=''>the</span> <span style=''>human</span> <span style=''>behavior</span> <span style=''>is</span> <span style=''>included</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style=''>model</span> <span style=''>checking</span> <span style=''>is</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Network</span> <span style=''>Maximal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlation</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>Network</span> <span style=''>Maximal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Correlation</span> <span style=''>(NMC)</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multivariate</span> <span style=''>measure</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>association</span> <span style=''>among</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>NMC</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>via</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>that</span> <span style=''>infers</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximizing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregate</span> <span style=''>inner</span> <span style=''>products</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transformed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>For</span> <span style=''>finite</span> <span style=''>discrete</span> <span style=''>and</span> <span style=''>jointly</span> <span style=''>Gaussian</span> <span style=''>random</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>characterize</span> <span style=''>a</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>NMC</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>using</span> <span style=''>basis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>basis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>For</span> <span style=''>finite</span> <span style=''>discrete</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expectation</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determine</span> <span style=''>NMC</span> <span style=''>Moreover</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>NMC</span> <span style=''>for</span> <span style=''>large</span> <span style=''>and</span> <span style=''>dense</span> <span style=''>graphs</span> <span style=''>using</span> <span style=''>gr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Lower</span> <span style=''>Bounds</span> <span style=''>for</span> <span style=''>BMRM</span> <span style=''>and</span> <span style=''>Faster</span> <span style=''>Rates</span> <span style=''>for</span> <span style=''>Training</span> <span style=''>SVMs</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.36000000000000004);'>Regularized</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>with</span> <span style=''>the</span> <span style=''>binary</span> <span style=''>hinge</span> <span style=''>loss</span> <span style=''>and</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>lies</span> <span style=''>at</span> <span style=''>the</span> <span style=''>heart</span> <span style=''>of</span> <span style=''>many</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>Bundle</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.36000000000000004);'>regularized</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>(BMRM)</span> <span style=''>and</span> <span style=''>the</span> <span style=''>closely</span> <span style=''>related</span> <span style=''>SVMStruct</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considered</span> <span style=''>the</span> <span style=''>best</span> <span style=''>general</span> <span style=''>purpose</span> <span style=''>solvers</span> <span style=''>to</span> <span style=''>tackle</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>It</span> <span style=''>was</span> <span style=''>recently</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>BMRM</span> <span style=''>requires</span> <span style=''>O(1epsilon)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>an</span> <span style=''>epsilon</span> <span style=''>accurate</span> <span style=''>solution</span> <span style=''>In</span> <span style=''>the</span> <span style=''>first</span> <span style=''>part</span> <span style=''>of</span> <span style=''>the</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>use</span> <span style=''>the</span> <span style=''>Hadamard</span> <span style=''>matrix</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.36000000000000004);'>regularized</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>these</span> <span style=''>rates</span> <span style=''>cannot</span> <span style=''>be</span> <span style=''>improved</span> <span style=''>We</span> <span style=''>then</span> <span style=''>show</span> <span style=''>how</span> <span style=''>one</span> <span style=''>can</span> <span style=''>exploit</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>to</span> <span style=''>devise</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>the</span> <span style=''>binary</span> <span style=''>hinge</span> <span style=''>loss</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.47058823529411753);'>converges</span> <span style=''>to</span> <span style=''>an</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Regulating</span> <span style=''>Greed</span> <span style=''>Over</span> <span style=''>Time</span> <br/><br/><span style=''>In</span> <span style=''>retail</span> <span style=''>there</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predictable</span> <span style=''>yet</span> <span style=''>dramatic</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>patterns</span> <span style=''>in</span> <span style=''>customer</span> <span style=''>behavior</span> <span style=''>such</span> <span style=''>as</span> <span style=''>periodic</span> <span style=''>changes</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>visitors</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increases</span> <span style=''>in</span> <span style=''>visitors</span> <span style=''>just</span> <span style=''>before</span> <span style=''>major</span> <span style=''>holidays</span> <span style=''>The</span> <span style=''>current</span> <span style=''>paradigm</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>analysis</span> <span style=''>does</span> <span style=''>not</span> <span style=''>take</span> <span style=''>these</span> <span style=''>known</span> <span style=''>patterns</span> <span style=''>into</span> <span style=''>account</span> <span style=''>This</span> <span style=''>means</span> <span style=''>that</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>in</span> <span style=''>retail</span> <span style=''>where</span> <span style=''>prices</span> <span style=''>are</span> <span style=''>fixed</span> <span style=''>for</span> <span style=''>periods</span> <span style=''>of</span> <span style=''>time</span> <span style=''>current</span> <span style=''>bandit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>will</span> <span style=''>not</span> <span style=''>suffice</span> <span style=''>This</span> <span style=''>work</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>remedy</span> <span style=''>that</span> <span style=''>takes</span> <span style=''>the</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>patterns</span> <span style=''>into</span> <span style=''>account</span> <span style=''>and</span> <span style=''>we</span> <span style=''>show</span> <span style=''>how</span> <span style=''>this</span> <span style=''>remedy</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implemented</span> <span style=''>in</span> <span style=''>the</span> <span style=''>UCB</span> <span style=''>and</span> <span style=''>epsilon</span> <span style=''>greedy</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>policy</span> <span style=''>called</span> <span style=''>the</span> <span style=''>variable</span> <span style=''>arm</span> <span style=''>pool</span> <span style=''>method</span> <span style=''>In</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corrected</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>(greed)</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regulated</span> <span style=''>over</span> <span style=''>time</span> <span style=''>so</span> <span style=''>that</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0. ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10381733856582233)
# 	knowledge (0.11844452372458081)
# 	representation (0.12950410274705673)
# 	experimental (0.1337852301105958)
# 	architecture (0.0952550838387442)
# 	information (0.2393863717445594)
# 	detection (0.11951480556546558)
# 	convolutional (0.13021762397431325)
# 	different (0.2689975026757046)
# 	recognition (0.13235818765608276)
#
# Some Statistics words are:
# 	variables (0.1402103154732098)
# 	estimation (0.17175763645468203)
# 	stochastic (0.1412118177265899)
# 	algorithm (0.39459188783174765)
# 	theoretical (0.15823735603405106)
# 	statistical (0.157235853780671)
# 	distribution (0.18477716574862293)
# 	inference (0.19879819729594392)
# 	regression (0.171256885327992)
# 	dimensional (0.19328993490235352)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5009d4e8-3d80-4ca6-8819-cc32a69e777c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5009d4e8-3d80-4ca6-8819-cc32a69e777c")) {                    Plotly.newPlot(                        "5009d4e8-3d80-4ca6-8819-cc32a69e777c",                        [{"x":["individual","generalizes","challenging","applications","experiments","generalize","important","continuous","imitation","parametrized","reinforcement","potential","variations","requiring","knowledge","principled","approaches","nonlinear","impractical","especially","implement","requirements","considered","households","consumption","recommended","algorithm","discussed","residential","techniques","prediction","literature","predictions","efficient","deployments","recurrent","forecasting","uncertainty","framework","performance","activations","questions","concatenates","convolutional","information","visualize","published","constitutes","understand","synthetic","architecture","inference","captioning","mechanism","answering","computing","exploring","understanding","attention","specifically","different","considers","adaptation","significantly","improving","recognition","preserving","generative","realistic","experimentally","alignment","synthesize","statistics","correlation","leverages","classifiers","augmenting","algorithms","photorealistic","statistic","discrepancy","benchmark","generated","including","reasoning","effective","semantics","arbitrary","aggregates","introduce","representing","declarative","representation","probability","consequently","interesting","aggregate","classical","nonmonotonic","disjunctive","programming","algebraic","similarity","equivalence","iterative","existence","considering","application","criterion","relationship","immediate","subtraction","properties","alzheimers","hippocampal","automatic","cognitive","promising","diagnostics","augmentation","determination","balancing","diagnosis","impairment","diffusion","extraction","comparison","furthermore","modalities","resonance","classification","initiative","tomography","structural","alzheimer","neuroimaging","extensive","functional","direction","supervised","decisions","processing","perception","rationality","possibilities","incorporation","conditions","normative","emergency","prescriptive","technological","addresses","searching","descriptive","presented","classifying","numerical","regarding","surveying","conclusions","usefulness","deblurring","degradation","improvements","experimental","redundancies","resolution","desirable","observation","characterizing","processes","projection","competitive","consistencies","achieving","denoising","optimized","interleaved","efficiently","architectures","restoration","denoisers","rotations","structured","collections","collection","trainable","documents","emulating","background","substrate","performed","historical","containing","handwritten","structures","production","disjunction","minimization","threshold","convergence","empirical","classifier","available","misleading","artificial","averaging","intelligence","currently","abduction","transduction","reduction","likelihood","hierarchical","attribute","parameterizations","dimensionality","spatiotemporal","observations","iterations","estimator","mathematical","determining","neocortex","formalization","comprehensive","component","mechanisms","procedure","locations","statistical","contained","demonstrate","selection","sometimes","reference","situation","coordinates","detection","hypotheses","discriminant","facilitate","involving","systematic","increases","formalized","previously","underlies","specification","biomarkers","investigators","predictive","represented","excessive","geometrical","transformation","elementary","describes","probabilisti ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	underlies
# 	parallelizing
# 	precisionk
# 	degeneracy
# 	timestamp
# 	surrogates
# 	unbiasedness
# 	stragglers
# 	staleness
# 	straggler
# 	seasonality
# 	suspected
# 	missforest
# 	unavoidably
# 	generalises
# 	spectrograms
# 	maturation
# 	timelines
# 	subsamples
# 	embarrassingly
# Some words which never appear in Statistics papers:
# 	households
# 	concatenates
# 	photorealistic
# 	nonmonotonic
# 	disjunctive
# 	subtraction
# 	alzheimer
# 	deblurring
# 	consistencies
# 	denoisers
# 	rotations
# 	substrate
# 	abduction
# 	presently
# 	specifications
# 	researches
# 	rotational
# 	prohibition
# 	backtracking
# 	possibilistic

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0724797984453255e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7691666666666667
